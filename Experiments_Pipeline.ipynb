# %% [markdown]
# ## Setup

# %%
import torchvision.transforms as tfs
from src.models.utils import download_checkpoint, load_model
from src.experiments import *
from src.visualization import *
from src.optimization import *
from IPython.display import Image 

checkpoint_path = download_checkpoint("https://drive.google.com/file/d/19m_SaRNEF7JXHjeyNu26AxgaEQXqpI00", "protopnet.pt")
model = load_model('protopnet', checkpoint_path, device="cuda")
ptypes = [(0,i) for i in range(model.num_prototypes // model.num_classes)]
image = visualize_prototypes(model, ptypes, optimization_steps=100)

pilimg = tfs.ToPILImage()(image.squeeze(0))
display(pilimg)
# Out:
# Downloading the checkpoint...
# 11862it [00:01, 8359.23it/s]
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to ./pretrained_models/resnet34-333f7ec4.pth
#   0%|          | 0.00/83.3M [00:00<?, ?B/s]
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F2D63D45150>

# %% [markdown]
# ## Optimized prototypes vs real prototypes

# %%
draw_optimized_prototypes_vs_real_prototypes(model)

# %% [markdown]
# ## Optimized prototypes vs real prototypes - distance histogram

# %%
draw_distance_histogram(model)
